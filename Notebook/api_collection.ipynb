# %%
import requests # To make HTTP requests
import pandas as pd # For data manipulation, specifically to transform responses JSON data to DataFrame
import os # To handle file paths
import logging # For logging execution messages
import time # To introduce delays between requests when getting rate-limited

# Configure logging messages format
logging.basicConfig(format='%(levelname)s: %(message)s')
logging.getLogger().setLevel(logging.INFO)

BASE_URL = "https://api.github.com/" # Base URL for the GitHub API

# %% [markdown]
# # Optional github API token set

# %%
GITHUB_TOKEN = input("Enter your GitHub token: ").strip()  # Prompt user for GitHub token

if GITHUB_TOKEN is None or GITHUB_TOKEN == "":
    logging.info("GITHUB_TOKEN was not set. Some endpoints may not work, others may return limited data and the rate limit is smaller.")
    GITHUB_TOKEN = None
else:
    logging.info("GITHUB_TOKEN is set.")
# Out:
# INFO: GITHUB_TOKEN was not set. Some endpoints may not work, others may return limited data and the rate limit is smaller.

# %% [markdown]
# # Utility functions
#
# Here I define some utility functions.

# %%
# Function to add authentication header if GITHUB_TOKEN was provided in the cell above
def add_auth_header_if_set(headers=None):
    """Add authentication header if GITHUB_TOKEN is provided."""
    if headers is None:
        headers = {}
    if GITHUB_TOKEN:
        headers['Authorization'] = f'Bearer {GITHUB_TOKEN}'
    return headers

# Function to save JSON response data to a JSON file
def save_json_to_file(data, filename, output_dir='output'):
    """Save JSON data to a file."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    file_path = os.path.join(output_dir, filename)
    with open(file_path, 'w') as f:
        import json
        json.dump(data, f, indent=4)
    logging.info(f"Data saved to {file_path}")

# Function to save JSON response data to a CSV file using pandas function 'json_normalize'
def save_json_to_csv(data, filename, output_dir='output'):
    """Save JSON data to a CSV file."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    file_path = os.path.join(output_dir, filename) 
    df = pd.json_normalize(data)
    df.to_csv(file_path, index=False)
    logging.info(f"Data saved to {file_path}")


# Function used to filter nested fields from the response dictionary got from the GitHub API
def extract_nested_fields(item, fields):
    """Recursively extract nested fields from a dictionary."""
    result = {}
    for field in fields:
        if isinstance(field, dict):
            # Handle nested fields like {"commit": ["message", {"author": ["name"]}]}
            for key, subfields in field.items():
                if key in item and isinstance(item[key], dict):
                    result[key] = extract_nested_fields(item[key], subfields)
        elif isinstance(field, str):
            # Handle simple string fields
            if field in item:
                result[field] = item[field]
    return result

# %% [markdown]
# # Rate limit check

# %%
def get_rate_limit():
    """Fetches the rate limit status for the authenticated user."""
    endpoint_path = "rate_limit"
    headers = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28"
    }
    headers = add_auth_header_if_set()
    response = requests.get(
        BASE_URL + endpoint_path,
        headers=headers
    )
    if response.status_code == 200:
        return response.json()
    else:
        logging.error(f"Failed to fetch rate limit: {response.status_code} - {response.text}")
        return []

# %%
rate_limit_json = get_rate_limit()
core_rate_limit = rate_limit_json.get('resources', {}).get('core', {})

# Calculate the time to reset the rate limit
reset_datetime = pd.to_datetime(core_rate_limit.get('reset', 'N/A'), unit='s', utc=True)
time_to_reset = reset_datetime - pd.Timestamp.utcnow()
time_to_reset_comps = time_to_reset.components

# Log the rate limit information
logging.info(f"Rate limit information for the current {'authenticated' if GITHUB_TOKEN else 'unauthenticated'} user:")
logging.info(f"Limit: {core_rate_limit.get('limit', 'N/A')}")
logging.info(f"Remaining: {core_rate_limit.get('remaining', 'N/A')}")
logging.info(f"Used: {core_rate_limit.get('used', 'N/A')}")
logging.info(f"Reset: {reset_datetime} (in {time_to_reset_comps.minutes}m {time_to_reset_comps.seconds}s)")
# Out:
# INFO: Rate limit information for the current unauthenticated user:
# INFO: Limit: 60
# INFO: Remaining: 52
# INFO: Used: 8
# INFO: Reset: 2025-06-24 04:41:45+00:00 (in 13m 24s)

# %% [markdown]
# # List public repositories
#
# Documentation: https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28#list-public-repositories

# %%
def get_public_repos(
        since_repository_id=None,
        filter_fields=False, fields=["name","description","html_url"]
    ):
    """Fetch repositories for a given organization."""
    
    endpoint_path = "/repositories"
    
    headers = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28"
    }
    headers = add_auth_header_if_set()
    
    query_params = {}
    if since_repository_id:
        if not isinstance(since_repository_id, int):
            raise ValueError("Since parameter must be an integer representing the repository ID.")
        query_params['since'] = since_repository_id
    
    response = requests.get(
        BASE_URL + endpoint_path + ("?" + "&".join(f"{key}={value}" for key, value in query_params.items()) if query_params else ""),
        headers=headers
    )

    if response.status_code == 200:
        if filter_fields:
            # Filter the response to include only specified fields
            contents = response.json()
            return [{key: item[key] for key in fields if key in item} for item in contents]
        else:
            return response.json()
    else:
        logging.error(f"Failed to fetch repositories: {response.status_code} - {response.text}")
        return []

# %%
response_json = get_public_repos(
    since_repository_id = 927842, 
    filter_fields=True)

save_json_to_file(response_json, "repos.json")  # Save the response to a file
save_json_to_csv(response_json, "repos.csv")  # Save the response to a CSV file
df = pd.json_normalize(response_json)  # Convert JSON to DataFrame
df
# Out:
# INFO: Data saved to output\repos.json
# INFO: Data saved to output\repos.csv
#                   name                                        description  \
# 0                unit1                       The unit 1 project for se362
# 1           soundslike         new search command filter based on soundex
# 2             rack-esi  An implementation of a small (but still very u...
# 3   batch_translations  Helpers to allow saving multiple Globalize2 tr...
# 4        sessionpicker                     A session picker for ScaleCamp
# ..                 ...                                                ...
# 95       MBProgressHUD  MBProgressHUD, an iOS activity indicator view ...
# 96              myspec                                               None
# 97       python-calais  my fork of python calais (for submodules, most...
# 98      erlmediaserver                            Erlang upnp mediaserver
# 99               store                                               None
#
#                                              html_url
# 0                    https://github.com/SageKaz/unit1
# 1               https://github.com/marinus/soundslike
# 2                     https://github.com/ook/rack-esi
# 3   https://github.com/eliasbaixas/batch_translations
# 4             https://github.com/dvydra/sessionpicker
# ..                                                ...
# 95      https://github.com/NickTrienens/MBProgressHUD
# 96                   https://github.com/mahhek/myspec
# 97          https://github.com/eyeseast/python-calais
# 98          https://github.com/joearms/erlmediaserver
# 99                      https://github.com/guan/store
#
# [100 rows x 3 columns]

# %% [markdown]
# # List organization repositories
#
# Documentation: https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28#list-organization-repositories

# %%
def get_org_repos(
        org,
        type=None, sort=None, direction=None,
        per_page=100, page=1,
        filter_fields=False, fields=["name","description","homepage","stargazers_count","watchers_count","created_at","updated_at","pushed_at","size","git_url","html_url"]
    ):

    """Fetch repositories for a given organization."""
    
    endpoint_path = "orgs/{org}/repos"
    
    headers = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28"
    }
    headers = add_auth_header_if_set()
    
    query_params = {}
    if type:
        if type not in ['all', 'public', 'private', 'forks', 'sources', 'member']:
            raise ValueError("Type must be one of: 'all', 'public', 'private', 'forks', 'sources', 'member'.")
        query_params['type'] = type
    if sort:
        if sort not in ['created', 'updated', 'pushed', 'full_name']:
            raise ValueError("Sort must be one of: 'created', 'updated', 'pushed', 'full_name'.")
        query_params['sort'] = sort
    if direction:
        if direction not in ['asc', 'desc']:
            raise ValueError("Direction must be either 'asc' or 'desc'.")
        query_params['direction'] = direction
    if per_page:
        if not isinstance(per_page, int) or per_page <= 0:
            raise ValueError("Per page must be a positive integer.")
        if per_page > 100:
            logging.warning("The maximum allowed per_page is 100, value was updated to 100.") # GitHub API allows a maximum of 100 items per page
            per_page = 100
        query_params['per_page'] = per_page
    if page:
        if not isinstance(page, int) or page <= 0:
            raise ValueError("Page must be a positive integer.")
        query_params['page'] = page

    response = requests.get(
        BASE_URL + endpoint_path.format(org=org) + ("?" + "&".join(f"{key}={value}" for key, value in query_params.items()) if query_params else "") ,
        headers=headers
    )
    
    if response.status_code == 200:
        if filter_fields:
            # Filter out fields that are not relevant
            contents = response.json()
            return [{key: item[key] for key in fields if key in item} for item in contents]
        else:
            # Return all contents including directories
            return response.json()
    
    else:
        logging.error(f"Failed to fetch repositories for '{org}': {response.status_code} - {response.json().get('message', 'No message')}")
        return []

# %%
response_json = get_org_repos(
    org = "freecodecamp", 
    type = "all",
    sort = "created",
    direction = "desc",
    per_page = 10,
    page = 1,
    filter_fields=True
    )

save_json_to_file(response_json, "org_repos.json")  # Save the response to a file
save_json_to_csv(response_json, "org_repos.csv")  # Save the response to a CSV file
df = pd.json_normalize(response_json)  # Convert JSON to DataFrame
df
# Out:
# INFO: Data saved to output\org_repos.json
# INFO: Data saved to output\org_repos.csv
#                                                 name  \
# 0                                       exam-creator
# 1                                 language-curricula
# 2                                         api-server
# 3                                   daily-challenges
# 4  learn-relational-databases-by-building-a-datab...
# 5                                 podcast-upload-app
# 6                                           exam-env
# 7                          campfire-vscode-extension
# 8                     articles-auto-translate-action
# 9                 article-webpage-to-markdown-action
#
#                                          description homepage  \
# 0                                               None     None
# 1  This repository will be used as a source for t...     None
# 2                 The legacy (loopback.io) based API     None
# 3                                               None     None
# 4                                               None     None
# 5                                               None     None
# 6  The freeCodeCamp Exam Environment desktop appl...
# 7                                               None     None
# 8                                               None     None
# 9  Automatically generate Markdown files based on...
#
#    stargazers_count  watchers_count            created_at  \
# 0                 0               0  2025-06-20T13:50:18Z
# 1                 0               0  2025-05-27T20:07:18Z
# 2                 1               1  2025-05-25T06:39:49Z
# 3                 0               0  2025-03-21T13:42:10Z
# 4                 3               3  2025-02-11T15:30:41Z
# 5                 0               0  2024-12-03T14:41:41Z
# 6                10              10  2024-11-11T23:38:45Z
# 7                 2               2  2024-09-04T15:27:49Z
# 8                 1               1  2024-07-28T07:12:28Z
# 9                 2               2  2024-06-29T14:54:41Z
#
#              updated_at             pushed_at  size  \
# 0  2025-06-23T12:25:58Z  2025-06-23T13:24:34Z   133
# 1  2025-05-27T20:43:01Z  2025-05-27T20:15:43Z   483
# 2  2025-06-18T20:48:02Z  2025-05-25T06:40:01Z  3548
# 3  2025-06-10T17:20:29Z  2025-06-10T17:20:26Z   100
# 4  2025-06-13T18:06:09Z  2025-02-11T18:21:24Z   539
# 5  2025-02-27T07:41:34Z  2024-12-05T08:24:10Z   215
# 6  2025-05-22T12:26:56Z  2025-05-22T12:42:39Z  2239
# 7  2025-02-27T07:41:26Z  2024-09-12T15:16:53Z   509
# 8  2025-02-05T10:07:38Z  2025-02-05T10:07:34Z   543
# 9  2025-02-27T07:41:20Z  2024-08-18T11:20:23Z  2228
#
#                                              git_url  \
# 0     git://github.com/freeCodeCamp/exam-creator.git
# 1  git://github.com/freeCodeCamp/language-curricu...
# 2       git://github.com/freeCodeCamp/api-server.git
# 3  git://github.com/freeCodeCamp/daily-challenges...
# 4  git://github.com/freeCodeCamp/learn-relational...
# 5  git://github.com/freeCodeCamp/podcast-upload-a...
# 6         git://github.com/freeCodeCamp/exam-env.git
# 7  git://github.com/freeCodeCamp/campfire-vscode-...
# 8  git://github.com/freeCodeCamp/articles-auto-tr...
# 9  git://github.com/freeCodeCamp/article-webpage-...
#
#                                             html_url
# 0       https://github.com/freeCodeCamp/exam-creator
# 1  https://github.com/freeCodeCamp/language-curri...
# 2         https://github.com/freeCodeCamp/api-server
# 3   https://github.com/freeCodeCamp/daily-challenges
# 4  https://github.com/freeCodeCamp/learn-relation...
# 5  https://github.com/freeCodeCamp/podcast-upload...
# 6           https://github.com/freeCodeCamp/exam-env
# 7  https://github.com/freeCodeCamp/campfire-vscod...
# 8  https://github.com/freeCodeCamp/articles-auto-...
# 9  https://github.com/freeCodeCamp/article-webpag...

# %% [markdown]
# # Get repository content
#
# Official documentation: https://docs.github.com/en/rest/repos/contents?apiVersion=2022-11-28#get-repository-content

# %%
def get_repo_contents(
        owner, repo, path="", 
        filter_fields=False, fields=["name","path","type","size","html_url","download_url"]):
    """Fetch contents of a repository."""
    
    endpoint_path = "repos/{owner}/{repo}/contents/{path}"
    
    headers = {
    "Accept": "application/vnd.github+json",
    "X-GitHub-Api-Version": "2022-11-28"
    }
    headers = add_auth_header_if_set(headers)

    

    response = requests.get(
        BASE_URL + endpoint_path.format(owner=owner, repo=repo, path=path),
        headers=headers
    )
    
    if response.status_code == 200:
        if filter_fields:
            contents = response.json()
            return [{key: item[key] for key in fields if key in item} for item in contents]
        else:
            return response.json()
    
    else:
        logging.error(f"Failed to fetch contents for '{owner}/{repo}': {response.status_code} - {response.json().get('message', 'No message')}")
        return []

# %%
response_json = get_repo_contents(
    owner = "freeCodeCamp", 
    repo = "freeCodeCamp", 
    path = "api/src", 
    
    filter_fields=True)  # Example usage, replace with your owner and repo

save_json_to_file(response_json, "repo_contents.json")
save_json_to_csv(response_json, "repo_contents.csv")
df = pd.json_normalize(response_json)
df
# Out:
# INFO: Data saved to output\repo_contents.json
# INFO: Data saved to output\repo_contents.csv
#                 name                      path  type  size  \
# 0             app.ts            api/src/app.ts  file  8409
# 1                 db                api/src/db   dir     0
# 2   exam-environment  api/src/exam-environment   dir     0
# 3      instrument.ts     api/src/instrument.ts  file   633
# 4            plugins           api/src/plugins   dir     0
# 5         reset.d.ts        api/src/reset.d.ts  file    37
# 6             routes            api/src/routes   dir     0
# 7     schema.test.ts    api/src/schema.test.ts  file  1892
# 8         schemas.ts        api/src/schemas.ts  file  3303
# 9            schemas           api/src/schemas   dir     0
# 10    server.test.ts    api/src/server.test.ts  file  2988
# 11         server.ts         api/src/server.ts  file   418
# 12             utils             api/src/utils   dir     0
#
#                                              html_url  \
# 0   https://github.com/freeCodeCamp/freeCodeCamp/b...
# 1   https://github.com/freeCodeCamp/freeCodeCamp/t...
# 2   https://github.com/freeCodeCamp/freeCodeCamp/t...
# 3   https://github.com/freeCodeCamp/freeCodeCamp/b...
# 4   https://github.com/freeCodeCamp/freeCodeCamp/t...
# 5   https://github.com/freeCodeCamp/freeCodeCamp/b...
# 6   https://github.com/freeCodeCamp/freeCodeCamp/t...
# 7   https://github.com/freeCodeCamp/freeCodeCamp/b...
# 8   https://github.com/freeCodeCamp/freeCodeCamp/b...
# 9   https://github.com/freeCodeCamp/freeCodeCamp/t...
# 10  https://github.com/freeCodeCamp/freeCodeCamp/b...
# 11  https://github.com/freeCodeCamp/freeCodeCamp/b...
# 12  https://github.com/freeCodeCamp/freeCodeCamp/t...
#
#                                          download_url
# 0   https://raw.githubusercontent.com/freeCodeCamp...
# 1                                                None
# 2                                                None
# 3   https://raw.githubusercontent.com/freeCodeCamp...
# 4                                                None
# 5   https://raw.githubusercontent.com/freeCodeCamp...
# 6                                                None
# 7   https://raw.githubusercontent.com/freeCodeCamp...
# 8   https://raw.githubusercontent.com/freeCodeCamp...
# 9                                                None
# 10  https://raw.githubusercontent.com/freeCodeCamp...
# 11  https://raw.githubusercontent.com/freeCodeCamp...
# 12                                               None

# %% [markdown]
# # Get commits list
#
# Official documentation: https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28#list-commits

# %%
def get_commits(
        owner, repo, 
        path=None, author=None,since=None, until=None, 
        per_page=None, page=None, 
        filter_fields=False, fields=["html_url", {"commit": ["message", {"author": ["name", "email", "date"]}, {"verification": ["verified"]}]}]
    ):
    
    endpoint_path = "repos/{owner}/{repo}/commits"

    headers = {
        "Accept": "application/vnd.github+json",
        "X-GitHub-Api-Version": "2022-11-28"
    }

    headers = add_auth_header_if_set(headers)
    
    query_params = {}
    if path:
        if not isinstance(path, str):
            raise ValueError("Path must be a string.")
        query_params['path'] = path
    if author:
        if not isinstance(author, str):
            raise ValueError("Author must be a string.")
        query_params['author'] = author
    if since:
        if not isinstance(since, str) or pd.to_datetime(since, errors='coerce') is pd.NaT:
            raise ValueError("Since must be a string in ISO 8601 format (e.g., '2023-01-01T00:00:00Z').") # GitHub API expects dates in ISO 8601 format
        query_params['since'] = since
    if until:
        if not isinstance(until, str) or pd.to_datetime(until, errors='coerce') is pd.NaT:
            raise ValueError("Until must be a string in ISO 8601 format (e.g., '2023-01-01T00:00:00Z').") # GitHub API expects dates in ISO 8601 format
        query_params['until'] = until
    if per_page:
        if not isinstance(per_page, int) or per_page <= 0:
            raise ValueError("Per page must be a positive integer.")
        if per_page > 100:
            logging.warning("The maximum allowed per_page is 100, value was updated to 100.") # GitHub API allows a maximum of 100 items per page
            per_page = 100
        query_params['per_page'] = per_page
    if page:
        if not isinstance(page, int) or page <= 0:
            raise ValueError("Page must be a positive integer.")
        query_params['page'] = page
    
    response = requests.get(
        BASE_URL + endpoint_path.format(owner=owner, repo=repo) + ("?" + "&".join(f"{key}={value}" for key, value in query_params.items()) if query_params else ""),
        headers=headers
    )
    
    if response.status_code == 200:
        if filter_fields:
            contents = response.json()
            return [extract_nested_fields(item, fields) for item in contents] # Extract only specified fields using the extract_nested_fields function defined at the beginning of the notebook
        else:
            return response.json()
    
    else:
        error_message = f"Failed to fetch commits: {response.status_code} - {response.json().get('message', 'No message')}"
        raise ValueError(error_message)

# %%
# response_json = get_commits("freeCodeCamp", "freeCodeCamp", filter_fields=True)
response_json = get_commits(
    per_page=10,
    page=1,
    owner = "freeCodeCamp", 
    repo = "freeCodeCamp",
    path = "api/src",
    author = "ojeytonwilliams@gmail.com",
    since = "2020-01-01T00:00:00Z",
    until = "2025-12-31T23:59:59Z",
    filter_fields=True
    )

save_json_to_file(response_json, "commits.json")
save_json_to_csv(response_json, "commits.csv")
df = pd.json_normalize(response_json)
df
# Out:
# INFO: Data saved to output\commits.json
# INFO: Data saved to output\commits.csv
#                                             html_url  \
# 0  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 1  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 2  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 3  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 4  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 5  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 6  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 7  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 8  https://github.com/freeCodeCamp/freeCodeCamp/c...
# 9  https://github.com/freeCodeCamp/freeCodeCamp/c...
#
#                                       commit.message     commit.author.name  \
# 0  fix(api): duplicate reply on error in /daily-c...  Oliver Eyton-Williams
# 1  chore(api): add user's id to errors sent to Se...  Oliver Eyton-Williams
# 2         chore(api): migrate to fastify v5 (#57576)  Oliver Eyton-Williams
# 3  fix: handle when userinfo has no email address...  Oliver Eyton-Williams
# 4  test: inform devs when db connection not estab...  Oliver Eyton-Williams
# 5  refactor: remove unused format rules from resp...  Oliver Eyton-Williams
# 6  test(api): stop reporting request logs during ...  Oliver Eyton-Williams
# 7    fix(api): handle expected Auth0 errors (#60499)  Oliver Eyton-Williams
# 8     fix(api): handle string challengeType (#60491)  Oliver Eyton-Williams
# 9  fix(api): handle users without email addresses...  Oliver Eyton-Williams
#
#          commit.author.email    commit.author.date  \
# 0  ojeytonwilliams@gmail.com  2025-06-23T13:15:26Z
# 1  ojeytonwilliams@gmail.com  2025-06-09T20:21:02Z
# 2  ojeytonwilliams@gmail.com  2025-06-02T02:37:57Z
# 3  ojeytonwilliams@gmail.com  2025-05-30T17:02:55Z
# 4  ojeytonwilliams@gmail.com  2025-05-28T15:52:11Z
# 5  ojeytonwilliams@gmail.com  2025-05-27T16:16:32Z
# 6  ojeytonwilliams@gmail.com  2025-05-27T16:05:25Z
# 7  ojeytonwilliams@gmail.com  2025-05-27T04:21:03Z
# 8  ojeytonwilliams@gmail.com  2025-05-23T12:56:18Z
# 9  ojeytonwilliams@gmail.com  2025-05-22T09:28:56Z
#
#    commit.verification.verified
# 0                          True
# 1                          True
# 2                          True
# 3                          True
# 4                          True
# 5                          True
# 6                          True
# 7                          True
# 8                          True
# 9                          True

# %% [markdown]
# # Get all commits list (iteration over pages)

# %%
def get_all_commits(
        owner, repo, 
        path=None, author=None,since=None, until=None, 
        per_page=100, max_pages=30, 
        filter_fields=False, fields=["html_url", {"commit": ["message", {"author": ["name", "email", "date"]}, {"verification": ["verified"]}]}]
    ):
    """Fetch all commits for a repository with pagination."""
    all_commits = []
    page = 1

    consecutive_rate_limit_exceeded = 0  # Counter for consecutive rate limit exceeded errors

    while page <= max_pages:
        try:
            commits = get_commits(
                owner=owner,
                repo=repo,
                path=path,
                author=author,
                since=since,
                until=until,
                per_page=per_page,
                page=page,
                filter_fields=filter_fields,
                fields=fields
            )
            
            logging.info(f"Page {page} fetched with {len(commits)} commits, total so far: {len(all_commits) + len(commits)}")
            
            if not commits:
                break  # No more commits to fetch
            
            all_commits.extend(commits)
            consecutive_rate_limit_exceeded = 0  # Reset counter if successful
            page += 1
        except Exception as e:
            logging.error(f"Error fetching commits on page {page}: {e}")
            
            # If returns "Not Found" error, it might be due to an invalid owner, repo, path, author or date range
            if "Not Found" in str(e):
                logging.error("Please check your string parameters and date ranges, the API failed to found data with the given parameters. Stopping further requests.")
                break # Stop further requests if the error is "Not Found"
            
            # If the rate limit is reached, wait for 60 seconds before retrying
            if "API rate limit exceeded" in str(e):
                
                consecutive_rate_limit_exceeded += 1 # Increment the counter for consecutive rate limit exceeded errors
                if consecutive_rate_limit_exceeded >= 3: # If rate limit exceeded 3 times, stop further requests
                    logging.error("Rate limit exceeded 3 times. Stopping further requests.")
                    logging.warning("Returning all commits fetched so far, the information may be incomplete.")
                    break
                
                # If the rate limit is exceeded, wait for 60 seconds before retrying
                logging.info("Rate limit exceeded. Waiting for 60 seconds before retrying...")
                time.sleep(60)
                logging.info("Retrying...") # Retry the iteration (avoiding page+=1)

    return all_commits

# %%
all_commits_json = get_all_commits(
    per_page=1,
    max_pages=100000,
    owner = "freeCodeCamp", 
    repo = "freeCodeCamp",
    path = "",
    since = "2020-01-01T00:00:00Z",
    until = "2025-12-31T23:59:59Z",
    filter_fields=True
    )
# Out:
# INFO: Page 1 fetched with 1 commits, total so far: 1
# INFO: Page 2 fetched with 1 commits, total so far: 2
# INFO: Page 3 fetched with 1 commits, total so far: 3
# INFO: Page 4 fetched with 1 commits, total so far: 4
# INFO: Page 5 fetched with 1 commits, total so far: 5
# INFO: Page 6 fetched with 1 commits, total so far: 6
# INFO: Page 7 fetched with 1 commits, total so far: 7
# INFO: Page 8 fetched with 1 commits, total so far: 8
# INFO: Page 9 fetched with 1 commits, total so far: 9
# INFO: Page 10 fetched with 1 commits, total so far: 10
# INFO: Page 11 fetched with 1 commits, total so far: 11
# INFO: Page 12 fetched with 1 commits, total so far: 12
# INFO: Page 13 fetched with 1 commits, total so far: 13
# INFO: Page 14 fetched with 1 commits, total so far: 14
# INFO: Page 15 fetched with 1 commits, total so far: 15
# INFO: Page 16 fetched with 1 commits, total so far: 16
# INFO: Page 17 fetched with 1 commits, total so far: 17
# INFO: Page 18 fetched with 1 commits, total so far: 18
# INFO: Page 19 fetched with 1 commits, total so far: 19
# INFO: Page 20 fetched with 1 commits, total so far: 20
# INFO: Page 21 fetched with 1 commits, total so far: 21
# INFO: Page 22 fetched with 1 commits, total so far: 22
# INFO: Page 23 fetched with 1 commits, total so far: 23
# INFO: Page 24 fetched with 1 commits, total so far: 24
# INFO: Page 25 fetched with 1 commits, total so far: 25
# INFO: Page 26 fetched with 1 commits, total so far: 26
# INFO: Page 27 fetched with 1 commits, total so far: 27
# INFO: Page 28 fetched with 1 commits, total so far: 28
# INFO: Page 29 fetched with 1 commits, total so far: 29
# INFO: Page 30 fetched with 1 commits, total so far: 30
# INFO: Page 31 fetched with 1 commits, total so far: 31
# INFO: Page 32 fetched with 1 commits, total so far: 32
# INFO: Page 33 fetched with 1 commits, total so far: 33
# INFO: Page 34 fetched with 1 commits, total so far: 34
# INFO: Page 35 fetched with 1 commits, total so far: 35
# INFO: Page 36 fetched with 1 commits, total so far: 36
# INFO: Page 37 fetched with 1 commits, total so far: 37
# INFO: Page 38 fetched with 1 commits, total so far: 38
# INFO: Page 39 fetched with 1 commits, total so far: 39
# INFO: Page 40 fetched with 1 commits, total so far: 40
# INFO: Page 41 fetched with 1 commits, total so far: 41
# INFO: Page 42 fetched with 1 commits, total so far: 42
# INFO: Page 43 fetched with 1 commits, total so far: 43
# INFO: Page 44 fetched with 1 commits, total so far: 44
# INFO: Page 45 fetched with 1 commits, total so far: 45
# INFO: Page 46 fetched with 1 commits, total so far: 46
# INFO: Page 47 fetched with 1 commits, total so far: 47
# INFO: Page 48 fetched with 1 commits, total so far: 48
# ERROR: Error fetching commits on page 49: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# INFO: Page 49 fetched with 1 commits, total so far: 49
# INFO: Page 50 fetched with 1 commits, total so far: 50
# INFO: Page 51 fetched with 1 commits, total so far: 51
# ERROR: Error fetching commits on page 52: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# INFO: Page 52 fetched with 1 commits, total so far: 52
# INFO: Page 53 fetched with 1 commits, total so far: 53
# INFO: Page 54 fetched with 1 commits, total so far: 54
# INFO: Page 55 fetched with 1 commits, total so far: 55
# INFO: Page 56 fetched with 1 commits, total so far: 56
# INFO: Page 57 fetched with 1 commits, total so far: 57
# INFO: Page 58 fetched with 1 commits, total so far: 58
# INFO: Page 59 fetched with 1 commits, total so far: 59
# INFO: Page 60 fetched with 1 commits, total so far: 60
# INFO: Page 61 fetched with 1 commits, total so far: 61
# INFO: Page 62 fetched with 1 commits, total so far: 62
# INFO: Page 63 fetched with 1 commits, total so far: 63
# INFO: Page 64 fetched with 1 commits, total so far: 64
# INFO: Page 65 fetched with 1 commits, total so far: 65
# INFO: Page 66 fetched with 1 commits, total so far: 66
# INFO: Page 67 fetched with 1 commits, total so far: 67
# INFO: Page 68 fetched with 1 commits, total so far: 68
# INFO: Page 69 fetched with 1 commits, total so far: 69
# INFO: Page 70 fetched with 1 commits, total so far: 70
# INFO: Page 71 fetched with 1 commits, total so far: 71
# INFO: Page 72 fetched with 1 commits, total so far: 72
# INFO: Page 73 fetched with 1 commits, total so far: 73
# INFO: Page 74 fetched with 1 commits, total so far: 74
# INFO: Page 75 fetched with 1 commits, total so far: 75
# INFO: Page 76 fetched with 1 commits, total so far: 76
# INFO: Page 77 fetched with 1 commits, total so far: 77
# INFO: Page 78 fetched with 1 commits, total so far: 78
# INFO: Page 79 fetched with 1 commits, total so far: 79
# INFO: Page 80 fetched with 1 commits, total so far: 80
# INFO: Page 81 fetched with 1 commits, total so far: 81
# INFO: Page 82 fetched with 1 commits, total so far: 82
# INFO: Page 83 fetched with 1 commits, total so far: 83
# INFO: Page 84 fetched with 1 commits, total so far: 84
# INFO: Page 85 fetched with 1 commits, total so far: 85
# INFO: Page 86 fetched with 1 commits, total so far: 86
# INFO: Page 87 fetched with 1 commits, total so far: 87
# INFO: Page 88 fetched with 1 commits, total so far: 88
# INFO: Page 89 fetched with 1 commits, total so far: 89
# INFO: Page 90 fetched with 1 commits, total so far: 90
# INFO: Page 91 fetched with 1 commits, total so far: 91
# INFO: Page 92 fetched with 1 commits, total so far: 92
# INFO: Page 93 fetched with 1 commits, total so far: 93
# INFO: Page 94 fetched with 1 commits, total so far: 94
# INFO: Page 95 fetched with 1 commits, total so far: 95
# INFO: Page 96 fetched with 1 commits, total so far: 96
# INFO: Page 97 fetched with 1 commits, total so far: 97
# INFO: Page 98 fetched with 1 commits, total so far: 98
# INFO: Page 99 fetched with 1 commits, total so far: 99
# INFO: Page 100 fetched with 1 commits, total so far: 100
# INFO: Page 101 fetched with 1 commits, total so far: 101
# INFO: Page 102 fetched with 1 commits, total so far: 102
# INFO: Page 103 fetched with 1 commits, total so far: 103
# INFO: Page 104 fetched with 1 commits, total so far: 104
# ERROR: Error fetching commits on page 105: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# ERROR: Error fetching commits on page 105: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# INFO: Page 105 fetched with 1 commits, total so far: 105
# INFO: Page 106 fetched with 1 commits, total so far: 106
# INFO: Page 107 fetched with 1 commits, total so far: 107
# INFO: Page 108 fetched with 1 commits, total so far: 108
# INFO: Page 109 fetched with 1 commits, total so far: 109
# INFO: Page 110 fetched with 1 commits, total so far: 110
# INFO: Page 111 fetched with 1 commits, total so far: 111
# INFO: Page 112 fetched with 1 commits, total so far: 112
# INFO: Page 113 fetched with 1 commits, total so far: 113
# INFO: Page 114 fetched with 1 commits, total so far: 114
# INFO: Page 115 fetched with 1 commits, total so far: 115
# INFO: Page 116 fetched with 1 commits, total so far: 116
# INFO: Page 117 fetched with 1 commits, total so far: 117
# INFO: Page 118 fetched with 1 commits, total so far: 118
# INFO: Page 119 fetched with 1 commits, total so far: 119
# INFO: Page 120 fetched with 1 commits, total so far: 120
# INFO: Page 121 fetched with 1 commits, total so far: 121
# INFO: Page 122 fetched with 1 commits, total so far: 122
# INFO: Page 123 fetched with 1 commits, total so far: 123
# INFO: Page 124 fetched with 1 commits, total so far: 124
# INFO: Page 125 fetched with 1 commits, total so far: 125
# INFO: Page 126 fetched with 1 commits, total so far: 126
# INFO: Page 127 fetched with 1 commits, total so far: 127
# INFO: Page 128 fetched with 1 commits, total so far: 128
# INFO: Page 129 fetched with 1 commits, total so far: 129
# INFO: Page 130 fetched with 1 commits, total so far: 130
# INFO: Page 131 fetched with 1 commits, total so far: 131
# INFO: Page 132 fetched with 1 commits, total so far: 132
# INFO: Page 133 fetched with 1 commits, total so far: 133
# INFO: Page 134 fetched with 1 commits, total so far: 134
# INFO: Page 135 fetched with 1 commits, total so far: 135
# INFO: Page 136 fetched with 1 commits, total so far: 136
# INFO: Page 137 fetched with 1 commits, total so far: 137
# INFO: Page 138 fetched with 1 commits, total so far: 138
# INFO: Page 139 fetched with 1 commits, total so far: 139
# INFO: Page 140 fetched with 1 commits, total so far: 140
# INFO: Page 141 fetched with 1 commits, total so far: 141
# INFO: Page 142 fetched with 1 commits, total so far: 142
# INFO: Page 143 fetched with 1 commits, total so far: 143
# INFO: Page 144 fetched with 1 commits, total so far: 144
# INFO: Page 145 fetched with 1 commits, total so far: 145
# INFO: Page 146 fetched with 1 commits, total so far: 146
# INFO: Page 147 fetched with 1 commits, total so far: 147
# INFO: Page 148 fetched with 1 commits, total so far: 148
# INFO: Page 149 fetched with 1 commits, total so far: 149
# INFO: Page 150 fetched with 1 commits, total so far: 150
# INFO: Page 151 fetched with 1 commits, total so far: 151
# INFO: Page 152 fetched with 1 commits, total so far: 152
# INFO: Page 153 fetched with 1 commits, total so far: 153
# INFO: Page 154 fetched with 1 commits, total so far: 154
# INFO: Page 155 fetched with 1 commits, total so far: 155
# INFO: Page 156 fetched with 1 commits, total so far: 156
# INFO: Page 157 fetched with 1 commits, total so far: 157
# INFO: Page 158 fetched with 1 commits, total so far: 158
# ERROR: Error fetching commits on page 159: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# ERROR: Error fetching commits on page 159: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# INFO: Rate limit exceeded. Waiting for 60 seconds before retrying...
# INFO: Retrying...
# ERROR: Error fetching commits on page 159: Failed to fetch commits: 403 - API rate limit exceeded for 189.203.235.161. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
# ERROR: Rate limit exceeded 3 times. Stopping further requests.
# WARNING: Returning all commits fetched so far, the information may be incomplete.

# %%
save_json_to_file(all_commits_json, "all_commits.json")
save_json_to_csv(all_commits_json, "all_commits.csv")
# Out:
# INFO: Data saved to output\all_commits.json
# INFO: Data saved to output\all_commits.csv
